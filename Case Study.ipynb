# %% [markdown]
# Question 1 : What are the issues you would want to investigate in diagnosing the condition of the current school system in Loravia?
#
#
#
# Answer : So in a good education system , both a good quality and good quantity of education is imparted to the common multitude ; So i idea will be to check how both of them can be imparted :
#     *  To check the quality of the teachers (their qualifications )
#     *  The quality of the curriculum in the schools ; outdated curriculum may result in a lower international score.
#     *  Supply of resourses to school like lab equipments
#     *  General mental health of students .
#     *  Socio-economic conditions of the families .
#     *  Access to education to a wider age-range .

# %% [markdown]
# Answer 2 :  So when data is observed , it is seen that although Loravia spends more than that similar sized nation yet its international rating is lower than rest of them .
# Loravia has a lower student-teacher ratio than the rest of the similar sized nations .
# The developed nations have higher spending and a better  international assessment score .
#
# Probably this tells us that although the government spends more money on the students yet it the utilization is questionable . The funds dont seems to reach where they are supposed to. Also issues like teacher quality and curriculum quality be investigated .

# %% [markdown]
# Question 3 : Given that Loravia has 20 million population we can calculation that exactly 3 million people are attending schools in Loravia .
# also 3 million by 500 gives us 6000 schools .
# Neighbour C has 800 students per school so considering that we have 3750 schools . Therefore 2250 schools need to be closed .
# The idea of closing the schools wouldnt be that productive as entire restructuring of the schools and shifting of staff would be tedious . Also the fact that students would need to travel a larger distance to reach their schools might cause them to dropout .In the end it would result in immense expenditures on ever side

# %% [markdown]
# Question 4 :  The fact that that the student-teacher ratio is less compared to the average europe student teacher ratio , the quality of teaching and the content of the curriculum are important issues to investigate thoroughly. Also we can investigate on possibilities for further and specialised education in Loravia . Also if there is a possible dropout of students .

# %%
.15 * 20
# Out:
# 3.0

# %%
3/800
# Out:
# 0.00375

# %%
6000 - 3750
# Out:
# 2250

# %%
import pandas as pd

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('file:///C:/Users/Rudrashis%20Gorai/Desktop/Sheet1.csv')

# %%
data
# Out:
#     Unnamed: 0  Students per school  Students per teacher  \
# 0      Loravia                  500                    18
# 1  Neighbour A                  400                    16
# 2  Neighbour B                  700                    20
# 3  Neighbour C                  800                    20
# 4  Developed A                  500                    21
# 5  Developed B                  350                    23
# 6  Developed C                  400                    20
# 7    Similar A                  600                    22
# 8    Similar B                  500                    20
# 9    Similar C                  300                    19
#
#    Government spending per student  Neighbour  Developed  Similar nation  \
# 0                             5000          0          0               0
# 1                             3000          1          0               0
# 2                             4000          1          0               0
# ...

# %%
# Out:
# 0    18
# 1    16
# 2    20
# 3    20
# 4    21
# 5    23
# 6    20
# 7    22
# 8    20
# 9    19
# Name: Students per teacher, dtype: int64

# %%
np.mean(data["Students per teacher"])
# Out:
# 19.9

# %%
np.mean(data["Students per school"])
# Out:
# 505.0

# %%
np.mean(data["Government spending per student"])
# Out:
# 5500.0

# %%
np.mean(data["intl. Assessment score"])
# Out:
# 46.7

# %%
sns
# Out:
# <module 'seaborn' from 'C:\\Users\\Rudrashis Gorai\\.anaconda\\lib\\site-packages\\seaborn\\__init__.py'>

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.distplot(data["intl. Assessment score"], kde = False)
# Out:
# C:\Users\Rudrashis Gorai\.anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(data)

# %%
sns.lmplot("intl. Assessment score","Students per school", data=data, fit_reg=False)

# %%
sns.lmplot("intl. Assessment score","Students per teacher", data=data, fit_reg=True)
# Out:
# C:\Users\Rudrashis Gorai\.anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot("intl. Assessment score","Government spending per student", data=data, fit_reg=True)
# Out:
# C:\Users\Rudrashis Gorai\.anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
pd.std((data["intl. Assessment score"]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-a631c7eae1dc> in <module>()
# ----> 1 pd.std((data["intl. Assessment score"]))
#
# AttributeError: module 'pandas' has no attribute 'std'

# %%
data.std(axis = 0)
# Out:
# Students per school                 157.144661
# Students per teacher                  1.969207
# Government spending per student    2198.484326
# Neighbour                             0.483046
# Developed                             0.483046
# Similar nation                        0.483046
# intl. Assessment score                5.735852
# dtype: float64

# %%
data.mean(axis=0)
# Out:
# Unnamed: 0                            0.0
# Students per school                 505.0
# Students per teacher                 19.9
# Government spending per student    5500.0
# Neighbour                             0.3
# Developed                             0.3
# Similar nation                        0.3
# intl. Assessment score               46.7
# dtype: float64

# %%
sns.kdeplot(data["intl. Assessment score"])
# Out:
# C:\Users\Rudrashis Gorai\.anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.kdeplot(data["Government spending per student"])
# Out:
# C:\Users\Rudrashis Gorai\.anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
